# %% [raw]
# ---
# title: "Tidy Tuesday Tweets Explorer"
# author: "LaughingRook"
# date: "2022-07-05"
# categories: [DuckDB, TidyTuesday]
# draft: true
# format:
#   html:
#     code-fold: false
#     code-tools: true
# ---

# %% [markdown]
# ## Summary
#
# Transform the CSV file of Tidy Tuesday tweets into a DuckDB.

# %% [markdown]
# ## Dependencies

# %%
import shutil
import tempfile
import urllib.request
import pandas as pd
import duckdb

# %% [markdown]
# ## Global constants

# %%
TWEETS_URL = ('https://raw.githubusercontent.com/rfordatascience/tidytuesday/'
              + 'master/tidytuesday_tweets/data.csv')

# %% [markdown]
# ## Main

# %% [markdown]
# ### Import the CSV file

# %%
with urllib.request.urlopen(TWEETS_URL) as response:
    with tempfile.NamedTemporaryFile(delete=False) as tmp_file:
        shutil.copyfileobj(response, tmp_file)

with open(tmp_file.name, encoding='utf8') as csv_f:
    tweets = pd.read_csv(csv_f, low_memory=False)

tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17284 entries, 0 to 17283
# Data columns (total 92 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   week                     17284 non-null  int64
#  1   user_id                  17284 non-null  int64
#  2   status_id                17284 non-null  int64
#  3   created_at               17284 non-null  object
#  4   screen_name              17284 non-null  object
#  5   text                     17284 non-null  object
#  6   source                   17283 non-null  object
#  7   display_text_width       17284 non-null  int64
#  8   reply_to_status_id       2244 non-null   float64
#  9   reply_to_user_id         2385 non-null   float64
#  10  reply_to_screen_name     2385 non-null   object
#  11  is_quote                 17284 non-null  bool
#  12  is_retweet               17284 non-null  bool
#  13  favorite_count           17284 non-null  int64
#  14  retweet_count            17284 non-null  int64
#  15  quote_count              0 non-null      float64
#  16  reply_count              0 non-null      float64
#  17  hashtags                 17248 non-null  object
#  18  symbols                  3 non-null      object
#  19  urls_url                 10061 non-null  object
#  20  urls_t.co                10061 non-null  object
#  21  urls_expanded_url        10061 non-null  object
#  22  media_url                11726 non-null  object
#  23  media_t.co               11726 non-null  object
#  24  media_expanded_url       11726 non-null  object
#  25  media_type               11726 non-null  object
#  26  ext_media_url            11726 non-null  object
#  27  ext_media_t.co           11726 non-null  object
#  28  ext_media_expanded_url   11726 non-null  object
#  29  ext_media_type           0 non-null      float64
#  30  mentions_user_id         5560 non-null   object
#  31  mentions_screen_name     5560 non-null   object
#  32  lang                     17284 non-null  object
#  33  quoted_status_id         1892 non-null   float64
#  34  quoted_text              1892 non-null   object
#  35  quoted_created_at        1892 non-null   object
#  36  quoted_source            1892 non-null   object
#  37  quoted_favorite_count    1892 non-null   float64
#  38  quoted_retweet_count     1892 non-null   float64
#  39  quoted_user_id           1892 non-null   float64
#  40  quoted_screen_name       1892 non-null   object
#  41  quoted_name              1892 non-null   object
#  42  quoted_followers_count   1892 non-null   float64
#  43  quoted_friends_count     1892 non-null   float64
#  44  quoted_statuses_count    1892 non-null   float64
#  45  quoted_location          1650 non-null   object
#  46  quoted_description       1864 non-null   object
#  47  quoted_verified          1892 non-null   object
#  48  retweet_status_id        0 non-null      float64
#  49  retweet_text             0 non-null      float64
#  50  retweet_created_at       0 non-null      float64
#  51  retweet_source           0 non-null      float64
#  52  retweet_favorite_count   0 non-null      float64
#  53  retweet_retweet_count    0 non-null      float64
#  54  retweet_user_id          0 non-null      float64
#  55  retweet_screen_name      0 non-null      float64
#  56  retweet_name             0 non-null      float64
#  57  retweet_followers_count  0 non-null      float64
#  58  retweet_friends_count    0 non-null      float64
#  59  retweet_statuses_count   0 non-null      float64
#  60  retweet_location         0 non-null      float64
#  61  retweet_description      0 non-null      float64
#  62  retweet_verified         0 non-null      float64
#  63  place_url                176 non-null    object
#  64  place_name               176 non-null    object
#  65  place_full_name          176 non-null    object
#  66  place_type               176 non-null    object
#  67  country                  176 non-null    object
#  68  country_code             176 non-null    object
#  69  geo_coords               17284 non-null  object
#  70  coords_coords            17284 non-null  object
#  71  bbox_coords              17284 non-null  object
#  72  status_url               17284 non-null  object
#  73  name                     17283 non-null  object
#  74  location                 13070 non-null  object
#  75  description              16265 non-null  object
#  76  url                      11579 non-null  object
#  77  protected                17284 non-null  bool
#  78  followers_count          17284 non-null  int64
#  79  friends_count            17284 non-null  int64
#  80  listed_count             17284 non-null  int64
#  81  statuses_count           17284 non-null  int64
#  82  favourites_count         17284 non-null  int64
#  83  account_created_at       17284 non-null  object
#  84  verified                 17284 non-null  bool
#  85  profile_url              11579 non-null  object
#  86  profile_expanded_url     11578 non-null  object
#  87  account_lang             0 non-null      float64
#  88  profile_banner_url       14361 non-null  object
#  89  profile_background_url   12296 non-null  object
#  90  profile_image_url        17284 non-null  object
#  91  ext_alt_text             456 non-null    object
# dtypes: bool(4), float64(28), int64(11), object(49)
# memory usage: 11.7+ MB

# %%
tweets.head()
# Out:
#    week             user_id           status_id           created_at  \
# 0    14          1241814552  980921600429252608  2018-04-02 21:35:08
# 1    14          1241814552  980921607492382722  2018-04-02 21:35:10
# 2    14          1241814552  980921611980300288  2018-04-02 21:35:11
# 3    14          1241814552  980950802759069697  2018-04-02 23:31:11
# 4    14  778773117036617732  980964560512405505  2018-04-03 00:25:51
#
#       screen_name                                               text  \
# 0     thomas_mock  Happy to announce the newest #R4DS online lear...
# 1     thomas_mock  MOST IMPORTANT RULE!\n\n0. Have fun! Connect w...
# 2     thomas_mock  4. Use the hashtag #TidyTuesday on Twitter if ...
# 3     thomas_mock  @umairdurrani87 That’s awesome! Make sure to t...
# 4  umairdurrani87  #TidyTuesday week one. Plot of average tuition...
#
#                source  display_text_width  reply_to_status_id  \
# 0  Twitter Web Client                 270                 NaN
# 1  Twitter Web Client                 198        9.809216e+17
# 2  Twitter Web Client                 101        9.809216e+17
# 3  Twitter for iPhone                  72        9.809419e+17
# 4  Twitter Web Client                  92                 NaN
#
#    reply_to_user_id  ... favourites_count   account_created_at  verified  \
# 0               NaN  ...            29237  2013-03-04 17:35:03     False
# 1      1.241815e+09  ...            29237  2013-03-04 17:35:03     False
# 2      1.241815e+09  ...            29237  2013-03-04 17:35:03     False
# 3      7.787731e+17  ...            29237  2013-03-04 17:35:03     False
# 4               NaN  ...             3463  2016-09-22 01:49:14     False
#
#                profile_url       profile_expanded_url  account_lang  \
# 0  https://t.co/uCjZToIacP     https://themockup.blog           NaN
# 1  https://t.co/uCjZToIacP     https://themockup.blog           NaN
# 2  https://t.co/uCjZToIacP     https://themockup.blog           NaN
# 3  https://t.co/uCjZToIacP     https://themockup.blog           NaN
# 4  https://t.co/wBRQELao7i  http://durraniu.github.io           NaN
#
#                                   profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/12418145...
# 1  https://pbs.twimg.com/profile_banners/12418145...
# 2  https://pbs.twimg.com/profile_banners/12418145...
# 3  https://pbs.twimg.com/profile_banners/12418145...
# 4                                                NaN
#
#                              profile_background_url  \
# 0  http://abs.twimg.com/images/themes/theme1/bg.png
# 1  http://abs.twimg.com/images/themes/theme1/bg.png
# 2  http://abs.twimg.com/images/themes/theme1/bg.png
# 3  http://abs.twimg.com/images/themes/theme1/bg.png
# 4  http://abs.twimg.com/images/themes/theme1/bg.png
#
#                                    profile_image_url ext_alt_text
# 0  http://pbs.twimg.com/profile_images/9515783812...          NaN
# 1  http://pbs.twimg.com/profile_images/9515783812...          NaN
# 2  http://pbs.twimg.com/profile_images/9515783812...          NaN
# 3  http://pbs.twimg.com/profile_images/9515783812...          NaN
# 4  http://pbs.twimg.com/profile_images/1284666844...          NaN
#
# [5 rows x 92 columns]
